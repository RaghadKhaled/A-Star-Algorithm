# %% [markdown]
# <font size="3">KINGDOM OF SAUDI ARABIA<br>
# Ministry of Higher Education<br>
# Al-Imam Mohammad University<br>
# College of Computer & Information Sciences<br><br>
#
#
# **Artificial Intelligence (CS361), Fall 2021**
# <br>**Instructor:
# Ms. Lujain Alawwad**
# <br><br>
# **Prepared by:**<br>
# - Alhanouf Almansour (440019183)<br>
# - Kholud Alnufaie (440020617)<br>
# - Raghad Albosais (440020209)<br>
# - Weaam Alghaith (440023306)<br>
#
#
# **Section: 373**

# %% [markdown]
# ## Contents<br><br>
#
#
# <font size="4">
#
# 1. [Introduction](#1.-Introduction)<br>
# 2. [Problem](#2.-Problem)<br>
#    2.1. [Problem explanation](#2.1.-Problem-explanation)<br>
#    2.2. [Problem formulation](#2.2.-Problem-formulation)<br>
# 3. [A* algorithm](#3.-A*-algorithm)<br>
#    3.1. [A* algorithm explanation](#3.1.-A*-algorithm-explanation)<br>
#    3.2. [A* algorithm properties](#3.2.-A*-algorithm-properties)<br>
#    3.3. [Heuristic functions](#3.3.-Heuristic-functions)<br>
#    3.4. [Pseudocode of the algorithm](#3.4.-Pseudocode-of-the-algorithm)<br>
#    3.5. [Implementation](#3.5.-Implementation)<br>
#    3.6. [Apply the algorithm on the problem](#3.6.-Apply-the-algorithm-on-the-problem)<br>
#    3.7. [Apply the algorithm on another sample](#3.7.-Apply-the-algorithm-on-another-sample)<br>
#    3.8. [Comparison on heuristics performance](#3.8.-Comparison-on-heuristics-performance)<br>
# 4. [References and resources](#4.-References-and-resources)<br>

# %% [markdown]
# <h2 dir="rtl">
# <font size="5">
# المحتويات <br><br>
#
#
# <font size="4">
#
# 1. [مقدمة](#1.-Introduction)<br>
# 2. [المشكلة](#2.-Problem)<br>
#     2.1. [شرح المشكلة](#2.1.-Problem-explanation)<br>
#     2.2. [صياغة المشكلة](#2.2.-Problem-formulation)<br>
# 3. [خوارزمية الإستار](#3.-A*-algorithm)<br>
#     3.1. [شرح خوارزمية الإستار](#3.1.-A*-algorithm-explanation)<br>
#     3.2. [خصائص خوارزمية الإستار](#3.2.-A*-algorithm-properties)<br>
#     3.3. [الطرق الإرشادية](#3.3.-Heuristic-functions)<br>
#     3.4. [خطوات عمل الخوارزمية](#3.4.-Pseudocode-of-the-algorithm)<br>
#     3.5. [التنفيذ للخوارزمية](#3.5.-Implementation)<br>
#     3.6. [تنفيذ الخوارزمية على العينة الأولى للمشكلة](#3.6.-Apply-the-algorithm-on-the-problem)<br>
#     3.7. [تنفيذ الخوارزمية على العينة الثانية للمشكلة](#3.7.-Apply-the-algorithm-on-another-sample)<br>
#     3.8. [المقارنة بين الطرق الإرشادية في أدائها](#3.8.-Comparison-on-heuristics-performance)<br>
# 4. [المراجع](#4.-References-and-resources)<br>
# </font>
# </h2>

# %% [markdown]
# ## 1. Introduction<br><br>
# <font size="3">
#
#
# Artificial Intelligence is the science of making agents think and act humanly and rationally. During this course, we were taught some of theoretical knowledge in AI and this project is a sheer implementation of that knowledge. The project is an
# interactive AI tutorial about Search problem.
# Search algorithms divided into two types(as illustrated in Figure1): Informed search algorithms and Uninformed search algorithms.
# The Uninformed Search (Blind Search) is searching without “information” about the goal node. Whereas The Informed Search (Heuristic Search) is searching with “information” about the goal node. We focus here on informed search algorithms, specifically A* and implement it to solve the Route-Finding Problem for emergency exit. We formulated the problem and explained how to implement the A* algorithms from scratch then applied the A* algorithm on the problem and compared between performance of heuristics used.

# %% [markdown]
# <h2 dir="rtl">
# <font size="5">
# 1. المقدمة <br><br>
# <font size="3">
# الذكاء الاصطناعي هو علم يجعل الوكيل (النظام الذكي) يفكر ويتصرف بإنسانية وعقلانية. خلال هذه المادة تطرقنا للجانب النظري في الذكاء الاصطناعي وفي هذا المشروع نطبق ما تعلمناه نظرياً بصورة عملية محضه. المشروع يستعرض تفاعلياً وعملياً مشاكل البحث في الذكاء الاصطناعي. تنقسم خوارزميات البحث إلى نوعين خوارزميات البحث المستنير وخوارزميات البحث غير المستنير. البحث غير المستنير (البحث الأعمى) يبحث بدون وجود أي "معلومة" ترشده إلى الهدف بينما البحث المستنير يبحث ولديه "معلومة" ترشده إلى هدفه. نركز هنا على خوارزميات البحث المستنير وخصوصاً الإستار وكيفية تنفيذها لتحل مشكلة تحديد طريق مخرج الطوارئ الأقرب. قمنا بصياغة المشكلة وشرح كيفية تطبيق الخوارزمية من الصفر على المشكلة التي تواجهنا. تم استخدام عدة طرق إرشادية وهي التي تساهم في توجيه الوكيل إلى الهدف الذي يتطلع إليه. بعد ذلك قارنا بين أداء الطرق الإرشادية المطبقة على المشكلة ذاتها.
#
# </font>
# </h2>

# %% [markdown]
# ![Search algorithm.jpg](data:image/jpeg;base64,...)
#
# Figure1: illustrate the search algorithm

# %% [markdown]
# ## 2. Problem
# ### 2.1. Problem explanation<br><br>
# <font size="3">
# A scenario where a fire occurred in a building and you would have to look for the nearest emergency exit in one floor of building depending on sign boards provided in the building.

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 2.1 شرح المشكلة
# <br><br>
# <font size="3">
# مواجهة مشكلة حدوث حريق في مبنى ويريد الشخص أن يذهب إلى أقرب مخرج طوارئ في الدور الذي هو متواجد فيه حاليا داخل المبنى معتمداً على اللوحات الإرشادية لمخارج الطوارئ الموجودة في كل دور داخل المبنى.
#
#
# </font>
# </h2>

# %%
from IPython.display import HTML
from base64 import b64encode
video_path = 'video_2021-12-09_23-36-34.mp4'

mp4 = open(video_path,'rb').read()
decoded_vid = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=400 controls><source src={decoded_vid} type="video/mp4"></video>')
# Out:
# This cell output is too large and can only be displayed while logged in.

# %% [markdown]
# Animation1: illustrate the problem explanation.

# %% [markdown]
# ### 2.2. Problem formulation<br><br>
# <font size="3">
#
#
# - Initial state: location of person that stops and looks to reach the nearest emergency exit.
# - Goal state: emergency exit.
# - Goal test: is the current state the emergency exit?
# - Actions: move from one sign board to another.
# - Successor function: gives us one of the possible adjacent sign board from the current sign board.
# - Path cost function: distance between two sign boards and between sign board  and emergency exit in meters.
# - Solution: is sequence of movement taken by the person from sign board to another until reaching the emergency exit with minimum path cost and least possible time.
# - State space: set of sign boards connected with each other to reach the emergency exit.

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 2.1 صياغة المشكلة
# <br><br>
# <font size="3">
# <br>-الحالة الابتدائية: موقع الشخص المبدئي والذي يتطلع من عنده للوصول إلى أقرب مخرج طوارئ .
# حالة الهدف: مخرج الطوارئ.<br>-
# اختبار الهدف:  ل وصلنا الى مخرج الطوارئ؟. <br>-
# الحركات:  الانتقال من لوحة إرشادية إلى أخرى. <br>-
# نموذج الإنتقال:   يقدم لنا واحدة من اللوحات الإرشادية المجاورة للوحة الإرشادية الحالية. <br>-
# قيمة الطريق:   المسافة بين كل لوحتين إرشاديتين وكل لوحة مع مخرج الطاورئ بالمتر. <br>-
# حل المشكلة: تسلسل الحركات التي اتخذها الشخص من لوحة إرشادية إلى آخر حتى يصل إلى مخرج الطوارئ مع الحد الأدنى من التكلفة الإجمالية للطريق وأقل وقت ممكن. <br>-
# فضاء الحالة:  مجموعة من اللوحات الإرشادية متصلة مع بعضها البعض للوصول إلى مخرج الطوارئ. <br>
# <br>
# <br></font></h2>

# %% [markdown]
# ![problem formulation.jpg](data:image/jpeg;base64,...)
#
# Figure2: illustrate the problem formulation

# %% [markdown]
# ## 3. A* algorithm
# ### 3.1. A* algorithm explanation<br><br>
# <font size="3">
#
# A * algorithm is a searching algorithm that searches for the shortest path between the initial and the final state. It is used in various applications.
#
# A* algorithm has 3 parameter f,g,and h
#
# Where is g  the cost of distance from the initial state to the current state. Basically, it is the sum of all the state that have been visited since leaving the first state.
#
# And h is also known as the heuristic value it is the estimated cost depends on various functions that calculates an approximate cost to a problem.
#
# And f it is the sum of g and h. So, f = g + h.

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 3.1 شرح خوارزمية الإيستار
# <br><br>
# <font size="3">
# مواجهة مشكلة حدوث حريق في مبنى ويريد الشخص أن يذهب إلى أقرب مخرج طوارئ في الدور الذي هو متواجد فيه حاليا داخل المبنى معتمداً على اللوحات الإرشادية لمخارج الطوارئ الموجودة
# من الحالة الإبتدائية إلى الحالة النهائية -الهدف-
# وتستخدم في عدة تطبيقات وهي تحتوي على ثلاث عناصر
# g
# وهي تكلفة المسافة بين الحالة الابتدائية إلى الحالة الحالية وهي في النهاية مجموع التكلفة  للمسافة الكلية من الحالة الابتدائية إلى الحالة النهائية
# h
# تعرف أيضا باسم قيمة استدلالية لانها قيمة محددة معتمدة على دالة تحسب التكلفة التقريبية لمشكلة ما
# f
# وهي مجموع g,h.
#
#
# </font>
# </h2>

# %% [markdown]
# ### 3.2. A* algorithm properties<br><br>
# <font size="3">
#
# A* is an informed search algorithm that has combines the properties taken from greedy search and uniform cost search for a more enhanced and accurate search. In greedy(Informed search), the algorithm that always takes the best immediate, or local, solution. whereas in the Uniform Cost Search (Uninformed Search) explores all possibilities and uses the lowest cumulative cost to find a path from the source to the destination.

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 3.2 خصائص خوارزمية الإيستار
# <br><br>
# <font size="3">
# A* هي خوارزمية بحث مستنير تجمع بين بين خصائص من البحث الجشع وبحث بالتكلفة الموحدة للحصول على بحث أكثر دقة . في البحث الجشع (بحث مستنير ) يكون دائما يأخذ أفضل حل حاليا بينما في البحث بالتكلفة الموحدة (بحث غير مستنير ) يستكشف جميع الاحتمالات ويستخدم التكلفة التجميعية للبحث عن الحل من المصدر إلى الوجهة.
#
#
# </font>
# </h2>

# %% [markdown]
# ![Algorithm propreties.jpg](data:image/png;base64,...)
#
# Figure3: illustrate the algorithm properties

# %% [markdown]
# ### 3.3. Heuristic functions<br><br>
# <font size="3">
#
# Heuristic is a function which is used in Informed Search, and it finds the most promising path. It takes the current state of the agent as its input and produces the estimation of how close agent is from the goal. The heuristic method, however, might not always give the best solution, but it guaranteed to find a good solution in reasonable time. Heuristic function estimates how close a state is to the goal. It is represented by h(n), and it calculates the cost of an optimal path between the pair of states. The value of the heuristic function is always positive.
#
# Here we used three heurstics functions. Eculidean distance,Manhattan distance and Steps.
# - Eculidean distance heurstic: is a heuristic function which measures the straight line distance between two points in n-dimensional space. the formula is
#
# ![Eculidean distance.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3">
#
# - Manhattan distance heurstic : is calculated as the sum of the absolute differences between the two vectors
# ![Manhattan distance.png](data:image/png;base64,...)
#
# - Steps heusruc: we defined this heuristic which calculates from point A to point B how many steps needed to walk by assuming the half meter equals one step.

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 2.1 الطرق الإرشادية
# <br><br>
# <font size="3">
# مواجهة مشكلة حدوث حريق في مبنى ويريد الشخص أن يذهب إلى أقرب مخرج طوارئ في الدور الذي هو متواجد فيه حاليا داخل المبنى معتمداً على اللوحات الإرشادية لمخارج الطوارئ الموجودةالطريقة الإرشادية تستخدم في البحث المستنير، وتجد المسار الواعد. يأخذ الحالة الحالية للوكيل كمدخل له وينتج تقدير مدى قرب الوكيل من الهدف. ومع ذلك، قد لا تقدم الطريقة الإرشادية دائمًا الحل الأفضل لكنها تضمن إيجاد حل جيد في وقت معقول. تقدر الطريقة الإرشادية مدى قرب العقدة من الهدف.
# يتم تمثيلها بواسطة h(n)
# وتحسب تكلفة المسار الأمثل بين زوج العقد. تكون قيمة الدالة الإرشادية عددية وهي موجبة دائما.<br><br>
# أستخدمنا ثلاث طرق إرشادية
# مسافة منهاتن، والمسافة الإقليدية، والخطوات.<br><br>
# المسافة الإقليدية الإرشادية: هي طريقة إرشادية تقيس مسافة الخط المستقيم بين نقطتين في فضاء متعدد الأبعاد. نقوم بحسابها باستخدام هذا القانون<br><br>
#
# ![Eculidean distance.png](data:image/png;base64,...)

# %% [markdown]
# <h2 dir="rtl">
# <font size="3">
# مسافة منهاتن: يتم حسابها على أنها مجموع الفروق المطلقة بين متجهين. نقوم بحسابها باستخدام هذا القانون<br>
#
# ![Manhattan distance.png](data:image/png;base64,...)
#
# <font size="3">
# <br>خطوات إرشادية: لقد حددنا هذا الاستدلال الذي يحسب من النقطة أ إلى النقطة ب عدد الخطوات اللازمة للمشي بافتراض أن نصف متر يساوي خطوة واحدة.
#
#
#
# </font>
# </h2>

# %% [markdown]
# #### Heurstic1 : Eculidean distance

# %% [markdown]
# | Sign board (State) | Heuristic1 (h) |
# |--------------|---------------|
# | A | 36|
# | B | 28 |
# | C | 35 |
# | D | 24 |
# | E | 32 |
# | F | 35 |
# | G | 20 |
# | H | 21 |
# | J | 22 |
# | K | 16 |
# | L | 0 |

# %% [markdown]
# #### Heurstic2 : Manhattan distance

# %% [markdown]
# | Sign board (State) | Heuristic1 (h) |
# |--------------|---------------|
# | A | 40 |
# | B | 38 |
# | C | 48 |
# | D | 37 |
# | E | 45 |
# | F | 49 |
# | G | 20 |
# | H | 25 |
# | J | 30 |
# | K | 20 |
# | L | 0 |

# %% [markdown]
# #### Heurstic3 : Steps

# %% [markdown]
# | Sign board (State) | Heuristic1 (h) |
# |--------------|---------------|
# | A | 38 |
# | B | 28 |
# | C | 31 |
# | D | 24 |
# | E | 13 |
# | F | 22 |
# | G | 18 |
# | H | 11 |
# | J | 11 |
# | K | 3 |
# | L | 0 |

# %% [markdown]
# ### 3.4. Pseudocode of the algorithm

# %% [markdown]
# <font size="3">
#
# A* Search Algorithm</font>
# 1.  Initialize the open list
# 2.  Initialize the closed list
#     put the starting node on the open
#     list (you can leave its f at zero)
#
# 3.  while the open list is not empty
#     a) find the node with the least f on
#        the open list, call it "q"
#
#     b) pop q off the open list
#
#     c) generate q's 8 successors and set their
#        parents to q
#
#     d) for each successor
#
#         i) if successor is the goal, stop search
#           successor.g = q.g + distance between
#                               successor and q
#           successor.h = distance from goal to
#           successor (This can be done using many
#           ways, we will discuss three heuristics-
#           Manhattan, Diagonal and Euclidean
#           Heuristics)
#
#           successor.f = successor.g + successor.h
#
#         ii) if a node with the same position as
#             successor is in the OPEN list which has a
#            lower f than successor, skip this successor
#
#         iii) if a node with the same position as
#             successor  is in the CLOSED list which has
#             a lower f than successor, skip this successor
#             otherwise, add  the node to the open list
#      end (for loop)
#
#     e) push q on the closed list
#     end (while loop)

# %% [markdown]
# ### 3.5. Implementation

# %%
import heapq


class Node:
    def __init__(self, cost, key, location, steps):
        self.cost = cost
        self.key = key
        self.location = location
        self.steps = steps


class PriorityQueue:
    def __init__(self):
        self._data = []
        self._index = 0

    def push(self , cost, key , steps, priority, location):
        heapq.heappush(self._data, (priority, Node(cost, key, location, steps)))
        self._index += 1

    def peek(self):
        if self.size() > 0:
            return self._data[0]
        else:
            return -1

    def pop(self):
        if len(self._data) > 0:
            return heapq.heappop(self._data)
        else:
            return None

    def Print(self):
        for i in range(len(self._data)):
            item = self._data[i][-1]
            if len(self._data) > 0:
                print('Data: ', item.data, 'Freq: ', item.frequency, 'Right: ', item.right, 'Left: ', item.left)
            else:
                print('Data: ', item.data, 'Freq: ', item.frequency)

    def size(self):
        return len(self._data)

# %%
class Graph:

    def __init__(self):
        self.nodes = dict() # key : Node
        self.Neighbour = dict() # key :
        self.cost = dict() # (A,B) : 10

    def add_node(self, cost, key, location, steps):
        self.nodes.update({key: Node(cost, key, location, steps)})
 # key : location
    def add_edge(self, a, b, cost):
        if self.Neighbour.get(a) == None:
            self.Neighbour.update({a : [b]})
        else:
            self.Neighbour.get(a).append(b)

        self.cost.update({(a, b): cost}) # A --- B

# %%
import math


def create_dic(graph_, start):
    """
    this method will initialize dictionary with infinite values for all nodes in the map.
    """
    score = dict()
    for node in graph_.nodes:
        score[node[0]] = math.inf
    score[start] = 0
    return score


def heuristic_function(graph_, a, b, option, current_key):
    """
    this method will calculate the heuristic value.
    _____________________________________________________________
   :param current_key: is the key of the current node.
   :param option: is number that will determine which heuristic function will used to find shortest path.
   :param a: is the location of starting node in the Map.
   :param b: is the location of ending node in the Map.
   :param graph_: is a graph contains nodes and edges.
   _____________________________________________________________
   :return: a list contains the shortest path from start to goal.
    """

    # if option is 1 then we use euclidean distance.
    if option == 1:
        return Euclidean_distance(a, b)
        # if option is 2 then we use manhattan distance.
    elif option == 2:
        return Manhattan_distance(a, b)
        # if option is 3 then we use steps heuristic.
    else:
        # current_key we use it to extract steps needs to reach the goal from the current node.
        return Steps(graph_, current_key)


def Steps(graph_, current_key):
    """
    :param graph_: is a graph contains nodes and edges.
    :param current_key: is the key of the current node.
    :return: the steps needs to reach the goal from the current node.
    """
    return graph_.nodes.get(current_key).steps


def goal_test(node, goal):
    """
    this method will check if node equal to goal.
    """
    return node == goal


def Manhattan_distance(a, b):

    (x1, y1) = a  # point a coordinates.
    (x2, y2) = b  # point b coordinates.

    return abs(x1-x2) + abs(y1-y2)


def Euclidean_distance(a, b):
    """
    this method will calculate the distance between two node.
    """
    (x1, y1) = a  # point a coordinates.
    (x2, y2) = b  # point b coordinates.

    return math.sqrt(((x1 - x2) ** 2) + ((y1 - y2) ** 2))


def generate_path(come_from, start, goal, path):
    """
    this method will return the shortest path list after we know the shortest path from start to goal. B: A ,
    """
    # path = []
    # start from the bottom.
    curr = goal
    # add goal to the list.
    path.append(goal)
    while curr != start:
        # insert in the beginning of the list.
        path.insert(0, come_from.get(curr))
        # update current to the next node.
        curr = come_from.get(curr)
    return path


def shortest_path(Graph_, start, goal, option_):
    """
    this method will returns the shortest path between a start point and a goal pint by using A* algorithm.
   _____________________________________________________________
   :param option_: is number that will determine which heuristic function will used to find shortest path.
   :param start:is the number of starting node in the Map.
   :param Graph_: is a graph.
   :param goal: is the number of target node in the Map.
   _____________________________________________________________
   :return: a list contains the shortest path from start to goal.
   """
    # we use this variable to count the number of visited nodes.
    num_expanded = 0
    # if something wrong
    if Graph_ is None or start is None or goal is None:
        return []
    # if starting node equal to goal.
    if goal_test(start, goal):
        return [start]

    # Initialize data structures.
    closed_set = set()  # set for store all explore nodes.
    open_queue = PriorityQueue()  # Queue for store nodes according to its priority which is (f(n)= g(n) +h(n)).
    open_dic = dict()  # this dictionary will track the content of the queue ( for fast look up).
    come_from = {start: None}  # this dictionary will store the parent of each node.
    g_score = create_dic(Graph_, start)  # this dictionary will store the costs of all nodes.
    path = []  # this list will store the shortest path from start to goal.
    Nodes = dict()  # this dictionary contains {key of node : node location(list)}.
    for key, Node in Graph_.nodes.items():
        Nodes.update({key: Node.location})
    Edges = Graph_.Neighbour  # this dictionary contains {key of node : children of that node(list)}.

    # insert the starting node in the open queue and open_dic
    open_queue.push(0, start, 0, 0, Nodes.get(start))
    open_dic.update({start: None})

    num_nodes_PQueue = 1

    while open_queue.size() > 0:
        # pop the node that has the smallest f(n) from the queue.
        curr_node = open_queue.pop()

        # if the current node is equal to the goal.
        if goal_test(curr_node[1].key, goal):
            path = generate_path(come_from, start, goal, path)
            break

        # add the current node to the explore set.
        closed_set.add(curr_node[1].key)
        num_expanded = num_expanded + 1
        # after we popped node from the queue(open_queue) we have to remove it from the open_dic.
        open_dic.pop(curr_node[1].key)

        # bring all children of the current node and do all these instructions for each.
        for k in Edges.get(curr_node[1].key):
            # if the child is not in explore set.
            if k not in closed_set:
                # calculate the heuristic value for the child.
                h = heuristic_function(Graph_, Nodes[k], Nodes.get(goal), option_, k)
                # calculate the cost value for the child.
                g = curr_node[1].cost + Graph_.cost.get((curr_node[1].key, k))
                # the total cost.
                f = g + h

                """if the child is in open_dic and the total cost is greater than or equal to the previous cost for 
                this child then skipped this child."""
                if k in open_dic and f >= g_score[k]:
                    continue
                # else insert child (I=key of the node,g=the cost of the node,f =total cost) to open_queue and open_dic.
                open_queue.push(g, k, curr_node[1].steps, f, Nodes.get(k))
                open_dic.update({k: f})
                num_nodes_PQueue = num_nodes_PQueue + 1
                # update cost of this child in g_cost.
                g_score.update({k: f})
                # change the parent of this child.
                come_from[k] = curr_node[1].key

    print("Number of vested nodes: " , num_expanded , " h(n): ", option_)
    print("Number of nodes in the queue: " , num_nodes_PQueue , " h(n): ", option_)
    return path

# %%
from time import perf_counter_ns
import time


# execute A* algorithm with different heuristics.
def execute(choice, graph):

    # record start time in milliseconds.
    start_time_ms = perf_counter_ns()

    # record start time in seconds.
    start_time_s = time.perf_counter()

    # store the shortest path in result variable.
    result = shortest_path(graph, 'A', 'L', choice)

    # record end time in milliseconds.
    end_time_s = time.perf_counter()

    # record end time in seconds.
    end_time_ms = perf_counter_ns()

    # print performance in milliseconds.
    print('Performance_in_ms:', end_time_ms - start_time_ms)

    # print performance in seconds.
    print('Performance_in_s:', end_time_s - start_time_s)

    # print shortest path and which heuristic we used to reach this path.
    print('result_for_heuristic_', choice, ': ', result)

    # this line for clean output.
    print("\n ----------------------------------------------------------------\n")


# print nodes info.
def print_nodes_info(graph):
    for i in graph.nodes.items():
        print('key: ', i[1].key, 'location (x,y): ', i[1].location , 'Steps: ', i[1].steps)
    print('\n\n\n')


# print neighbors for each node.
def print_neighbors(graph):
    for i in graph.Neighbour.items():
        print('key: ', i[0], ' Neighbour: ', i[1])
    print('\n\n\n')

# %% [markdown]
# ### 3.6. Apply the algorithm on the problem (sample1)

# %%
import math


# Create graph
graph = Graph()

# Add nodes to graph
graph.add_node(0, 'A', (35, 50), 0)
graph.add_node(math.inf, 'B', (15, 28), 21)
graph.add_node(math.inf, 'C', (25, 48), 6)
graph.add_node(math.inf, 'D', (50, 37), 15)
graph.add_node(math.inf, 'E', (65, 35), 25)
graph.add_node(math.inf, 'F', (15, 39), 23)
graph.add_node(math.inf, 'G', (40, 35), 18)
graph.add_node(math.inf, 'H', (60, 20), 11)
graph.add_node(math.inf, 'J', (30, 35), 11)
graph.add_node(math.inf, 'K', (25, 20), 3)
graph.add_node(math.inf, 'L', (40, 15), 0)

# Add edges to graph
graph.add_edge('A', 'B', 42)
graph.add_edge('A', 'C', 12)
graph.add_edge('A', 'D', 29)
graph.add_edge('A', 'E', 50)
graph.add_edge('B', 'F', 11)
graph.add_edge('B', 'A', 42)
graph.add_edge('C', 'A', 12)
graph.add_edge('C', 'F', 20)
graph.add_edge('C', 'G', 20)
graph.add_edge('D', 'G', 7)
graph.add_edge('D', 'H', 31)
graph.add_edge('D', 'A', 29)
graph.add_edge('E', 'H', 9)
graph.add_edge('E', 'A', 50)
graph.add_edge('F', 'C', 20)
graph.add_edge('F', 'J', 22)
graph.add_edge('F', 'B', 11)
graph.add_edge('G', 'C', 20)
graph.add_edge('G', 'D', 7)
graph.add_edge('G', 'J', 10)
graph.add_edge('G', 'K', 30)
graph.add_edge('H', 'D', 31)
graph.add_edge('H', 'E', 9)
graph.add_edge('H', 'L', 16)
graph.add_edge('J', 'F', 22)
graph.add_edge('J', 'G', 10)
graph.add_edge('J', 'K', 17)
graph.add_edge('K', 'J', 17)
graph.add_edge('K', 'G', 30)
graph.add_edge('K', 'L', 5)
graph.add_edge('L', 'K', 5)
graph.add_edge('L', 'H', 16)


# print nodes info.
print_nodes_info(graph)

# print neighbors for each node.
print_neighbors(graph)
# Out:
# key:  A location (x,y):  (35, 50) Steps:  0
# key:  B location (x,y):  (15, 28) Steps:  21
# key:  C location (x,y):  (25, 48) Steps:  6
# key:  D location (x,y):  (50, 37) Steps:  15
# key:  E location (x,y):  (65, 35) Steps:  25
# key:  F location (x,y):  (15, 39) Steps:  23
# key:  G location (x,y):  (40, 35) Steps:  18
# key:  H location (x,y):  (60, 20) Steps:  11
# key:  J location (x,y):  (30, 35) Steps:  11
# key:  K location (x,y):  (25, 20) Steps:  3
# key:  L location (x,y):  (40, 15) Steps:  0
#
#
#
#
# key:  A  Neighbour:  ['B', 'C', 'D', 'E']
# key:  B  Neighbour:  ['F', 'A']
# key:  C  Neighbour:  ['A', 'F', 'G']
# key:  D  Neighbour:  ['G', 'H', 'A']
# key:  E  Neighbour:  ['H', 'A']
# key:  F  Neighbour:  ['C', 'J', 'B']
# key:  G  Neighbour:  ['C', 'D', 'J', 'K']
# key:  H  Neighbour:  ['D', 'E', 'L']
# key:  J  Neighbour:  ['F', 'G', 'K']
# key:  K  Neighbour:  ['J', 'G', 'L']
# key:  L  Neighbour:  ['K', 'H']

# %% [markdown]
# ![Eculidean distance heuristic.png](data:image/png;base64,...)

# %%
# execute A* algorithm with Euclidean distance heuristic.
execute(1, graph)
# Out:
# Number of vested nodes:  8  h(n):  1
# Number of nodes in the queue:  12  h(n):  1
# Performance_in_ms: 953600
# Performance_in_s: 0.0009524000001874811
# result_for_heuristic_ 1 :  ['A', 'C', 'G', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ![Manhattan distance heuristic.png](data:image/png;base64,...)

# %%
# execute A* algorithm with Manhattan distance heuristic.
execute(2, graph)
# Out:
# Number of vested nodes:  6  h(n):  2
# Number of nodes in the queue:  12  h(n):  2
# Performance_in_ms: 517100
# Performance_in_s: 0.0005163999999240332
# result_for_heuristic_ 2 :  ['A', 'C', 'G', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ![Steps heuristic.png](data:image/png;base64,...)

# %%
# execute A* algorithm with Steps heuristic.
execute(3, graph)
# Out:
# Number of vested nodes:  8  h(n):  3
# Number of nodes in the queue:  12  h(n):  3
# Performance_in_ms: 460100
# Performance_in_s: 0.00045899999986431794
# result_for_heuristic_ 3 :  ['A', 'C', 'G', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ### 3.7. Apply the algorithm on another sample (sample2)

# %%
import math


# Create graph
graph = Graph()

# Add nodes to graph
graph.add_node(0, 'A', (35, 50), 0)
graph.add_node(math.inf, 'C', (25, 48), 6)
graph.add_node(math.inf, 'E', (65, 35), 25)
graph.add_node(math.inf, 'H', (60, 20), 11)
graph.add_node(math.inf, 'J', (30, 35), 11)
graph.add_node(math.inf, 'K', (25, 20), 3)
graph.add_node(math.inf, 'L', (40, 15), 0)

# Add edges to graph
graph.add_edge('A', 'C', 35)
graph.add_edge('A', 'E', 60)
graph.add_edge('C', 'A', 35)
graph.add_edge('C', 'J', 7)
graph.add_edge('E', 'H', 11)
graph.add_edge('E', 'A', 60)
graph.add_edge('H', 'E', 11)
graph.add_edge('H', 'L', 20)
graph.add_edge('J', 'C', 7)
graph.add_edge('J', 'K', 12)
graph.add_edge('K', 'J', 12)
graph.add_edge('K', 'L', 5)
graph.add_edge('L', 'K', 5)
graph.add_edge('L', 'H', 20)


# print nodes info.
print_nodes_info(graph)

# print neighbors for each node.
print_neighbors(graph)
# Out:
# key:  A location (x,y):  (35, 50) Steps:  0
# key:  C location (x,y):  (25, 48) Steps:  6
# key:  E location (x,y):  (65, 35) Steps:  25
# key:  H location (x,y):  (60, 20) Steps:  11
# key:  J location (x,y):  (30, 35) Steps:  11
# key:  K location (x,y):  (25, 20) Steps:  3
# key:  L location (x,y):  (40, 15) Steps:  0
#
#
#
#
# key:  A  Neighbour:  ['C', 'E']
# key:  C  Neighbour:  ['A', 'J']
# key:  E  Neighbour:  ['H', 'A']
# key:  H  Neighbour:  ['E', 'L']
# key:  J  Neighbour:  ['C', 'K']
# key:  K  Neighbour:  ['J', 'L']
# key:  L  Neighbour:  ['K', 'H']

# %% [markdown]
# ![sample2 eculidean.jpg](data:image/jpeg;base64,...)

# %%
# execute A* algorithm with Euclidean distance heuristic.
execute(1, graph)
# Out:
# Number of vested nodes:  4  h(n):  1
# Number of nodes in the queue:  6  h(n):  1
# Performance_in_ms: 276900
# Performance_in_s: 0.00027619999991657096
# result_for_heuristic_ 1 :  ['A', 'C', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ![sample2 manhattan.jpg](data:image/jpeg;base64,...)

# %%
# execute A* algorithm with Manhattan distance heuristic.
execute(2, graph)
# Out:
# Number of vested nodes:  4  h(n):  2
# Number of nodes in the queue:  6  h(n):  2
# Performance_in_ms: 407400
# Performance_in_s: 0.00040680000029169605
# result_for_heuristic_ 2 :  ['A', 'C', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ![sample2 steps.jpg](data:image/jpeg;base64,...)

# %%
# execute A* algorithm with Steps heuristic.
execute(3, graph)
# Out:
# Number of vested nodes:  4  h(n):  3
# Number of nodes in the queue:  6  h(n):  3
# Performance_in_ms: 877300
# Performance_in_s: 0.000876099999914004
# result_for_heuristic_ 3 :  ['A', 'C', 'J', 'K', 'L']
#
#  ----------------------------------------------------------------

# %% [markdown]
# ### 3.8. Comparison on heuristics performance<br><br>
#
#
# <font size="4">
# We've studies two cases when it comes to optimality of A*:
#
# - case 1- tree-search, the heuristic must be admissible (must be less than or equal to the real path cost from that state to the goal state h* (n), as follow h(n) ≤ h*(n)).
# - case 2- graph-search the heuristic must be consistent (the heuristic function of the current state must be less than or equal to the heuristic function of the successor state plus the step cost between them c(n,m), as follow h(n) ≤ c(n,m) + h(m)).
#
#
# <br>In our problem is implemented using the graph-search strategy. hence, focusing on the consistency to prove optimality.
# </font>

# %% [markdown]
# <h2 dir="rtl">
# <font size="4">
# 3.8 مقارنة حول أداء الطرق الإرشادية
# <br><br>
# <font size="3">
# لقد درسنا حالتين عندما يتعلق الأمر في خوارزمية A* المثالية:
# <h2 dir="rtl">
# <font size="3">
# <br>
# -
# الحالة الألى البحث باستخدام البحث الشجري ، يجب أن تكون طريقة الإستدلال مقبولة (يجب أن تكون قيمة طريقة الإستدلال أقل من أو تساوي القيمة الفعلية للطريق من أي حالة إلى حالة الهدف,على النحو التالي h (n) ≤ h * (n) )
#
# <br>
# -
# الحالة الثانية البحث باستخدام البحث البياني ، يجب أن تكون طريقة الإستدلال متسقة (يجب أن تكون قيمة طريقة الإستدلال للحالة الحالية أقل من أو تساوي قيمة طريقة الإستدلال للحالة التالية بالإضافة إلى تكلفة الخطوة بينهما,على النحو التالي h (n) ≤ c (n ، m) + h (m) )
# <br><br>
# <h2 dir="rtl">
# <font size="3">
# مشكلتنا تم تنفيذها باستخدام استراتيجية البحث البياني، بالتالي، سنركز على الاتساق لأثبات المثالية لخوارزمية A*.
#
#
# </font>
# </h2>

# %% [markdown]
# #### - The performance of heuristics regarding consistency
# After we applied the A* algorithm with eculidean distance and manhattan distance heuristic, we found the shortest path with lowest cost even that they are not consistency.

# %% [markdown]
# | Heurstics | Consistency |
# |---------------|---|
# | Eculidean distance | No |
# | Manhattan distance | No |
# | Steps | Yes |

# %% [markdown]
# #### - The performance of heuristics regarding time complexity, number of expanded nodes and number of nodes in fringe foe sample1
#
# We concluded for sample1, all heuristics have the same number of nodes in fringe but they are different in time complexity and number of expanded nodes.

# %% [markdown]
# | Heurstics | Time complexity | No. expanded nodes | No. fringe's nodes |
# |---------------|-----------------|------------------|------------------|
# | Eculidean distance | 214600 ms | 8 | 12 |
# | Manhattan distance | 155500 ms | 6 | 12 |
# | Steps | 192800 ms | 8 | 12 |

# %% [markdown]
# #### - The performance of heuristics regarding time complexity, number of expanded nodes and number of nodes in fringe in sample2
#
# We concluded for sample2, all heuristics have the same number of nodes in fringe and number of expanded nodes but they are different in time complexity.

# %% [markdown]
# | Heurstics | Time complexity | No. expanded nodes | No. fringe's nodes |
# |---------------|-----------------|------------------|------------------|
# | Eculidean distance | 276900 ms | 4 | 6 |
# | Manhattan distance | 407400 ms | 4 | 6 |
# | Steps | 877300 ms | 4 | 6 |

# %% [markdown]
# ## 4. References and resources
#
# - “A* Search Algorithm - GeeksforGeeks.” GeeksforGeeks, 7 Sept. 2018, www.geeksforgeeks.org/a-search-algorithm/.
#
# - “Euclidean Distance - Neo4j Graph Data Science.” Neo4j Graph Database Platform, https://neo4j.com/docs/graph-data-science/current/alpha-algorithms/euclidean/.
#
# - “Informed Search Algorithms in AI - Javatpoint.” Www.javatpoint.com, 2011, www.javatpoint.com/ai-informed-search-algorithms.
#
# - “Python - How to Play Videos on Google Colab While Using OpenCV?” Stack Overflow, https://stackoverflow.com/questions/61561234/how-to-play-videos-on-google-colab-while-using-opencv.
